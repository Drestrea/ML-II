# %% [markdown]
# ### Point 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# unsupervised.py

import numpy as np

class SVD:
    def __init__(self):
        pass

    def fit(self, X):
        # SVD fitting code here
        pass

    def transform(self, X):
        # SVD transformation code here
        pass

    def fit_transform(self, X):
        # Combined fit and transform code here
        pass


class PCA:
    def __init__(self, n_components):
        self.n_components = n_components

    def fit(self, X):
        # PCA fitting code here
        pass

    def transform(self, X):
        # PCA transformation code here
        pass

    def fit_transform(self, X):
        # combined fit and transform code here
        pass


class TSNE:
    def __init__(self, perplexity=30, n_iter=1000):
        self.perplexity = perplexity
        self.n_iter = n_iter

    def fit(self, X):
        # t-SNE fitting code here
        pass


    def transform(self, X):
        # t-SNE transformation code here
        pass


    def fit_transform(self, X):
        # Combined fit and transform code here
        pass
