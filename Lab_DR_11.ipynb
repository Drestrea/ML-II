# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from flask import Flask, request


app = Flask(__name__)

@app.route("/api", methods = ["POST"])
def buscador ():
    data = request.get_json()
    ######
    return {"message": "Data received", "data": data}, 200

# %%
import threading

def run_app():
    app.run(port=5000)

server_thread = threading.Thread(target=run_app)
server_thread.start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %%
import requests

response = requests.post('http://127.0.0.1:5000/api', json={"key": "value"})
print(response.json())
# Out:
# 127.0.0.1 - - [05/Sep/2023 18:43:42] "POST /api HTTP/1.1" 200 -
# {'data': {'key': 'value'}, 'message': 'Data received'}

# %%
server_thread._stop()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Somewhere else in your code, set the flag to True to stop the thread
# ----> 2 server_thread._stop()
#
# File C:\ProgramData\anaconda3\lib\threading.py:1047, in Thread._stop(self)
#    1045 lock = self._tstate_lock
#    1046 if lock is not None:
# -> 1047     assert not lock.locked()
#    1048 self._is_stopped = True
#    1049 self._tstate_lock = None
#
# AssertionError:
# 127.0.0.1 - - [05/Sep/2023 18:54:55] "GET /api HTTP/1.1" 405 -
